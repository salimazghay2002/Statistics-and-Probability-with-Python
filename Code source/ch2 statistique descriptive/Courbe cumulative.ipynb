# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Créer un ensemble de données
data = pd.read_excel("valeurs.xlsx")
print(data)

# Trier les données
sorted_data = np.sort(data)

# Calculer la fonction de répartition empirique
cumulative = np.cumsum(sorted_data) / np.sum(sorted_data)

# Tracer la courbe cumulative
plt.plot(sorted_data, cumulative)
plt.xlabel('Valeurs')
plt.ylabel('fréquences')
plt.title('Courbe cumulative des fréquences')
plt.show()
# Out:
#       1
# 0    10
# 1     9
# 2    19
# 3     1
# 4    15
# ..   ..
# 994   5
# 995  18
# 996   4
# 997   5
# 998  13
#
# [999 rows x 1 columns]

# %%
# Importer les bibliothèques
import pandas as pd
import statistics as stat
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.get_dataset_names()
data = sns.load_dataset('anagrams')
data
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5

# %%
# Tarcer diagramme en batôns
serie = pd.Series(data['num1'])
table_effectifs = serie.value_counts().reset_index()
table_effectifs.columns = ['Modalite', 'Effectif']
print(table_effectifs)

plt.bar(table_effectifs['Modalite'],table_effectifs['Effectif'])
plt.title('Diagramme en batôns')
plt.xlabel('Modalités')
plt.ylabel('Effectifs')
plt.show()
# Out:
#    Modalite  Effectif
# 0         5         5
# 1         6         5
# 2         8         3
# 3         2         2
# 4         3         2
# 5         7         2
# 6         4         1

# %%
sns.boxplot(x='num1',y='num3',data=data)
# Out:
# <Axes: xlabel='num1', ylabel='num3'>

# %%
import pandas as pd

donnees = [1, 2, 2, 3, 3, 3, 4, 5, 5, 5, 5
# Out:
#    Modalite  Effectif
# 0         5         4
# 1         3         3
# 2         2         2
# 3         1         1
# 4         4         1

# %%
import seaborn as sns

sns.get_dataset_names()
data = sns.load_dataset('anagrams')
print(data)

# Accès à la colonne contenant les données
colonne_mode = data['num1']

# Calcul du mode
mode = colonne_mode.median()

# Obtention du résultat
resultat = mode

# Affichage du mode
print("Le mode est :", resultat)
# Out:
#     subidr    attnr  num1  num2  num3
# 0        1  divided     2   4.0     7
# 1        2  divided     3   4.0     5
# 2        3  divided     3   5.0     6
# 3        4  divided     5   7.0     5
# 4        5  divided     4   5.0     8
# 5        6  divided     5   5.0     6
# 6        7  divided     5   4.5     6
# 7        8  divided     5   7.0     8
# 8        9  divided     2   3.0     7
# 9       10  divided     6   5.0     6
# 10      11  focused     6   5.0     6
# 11      12  focused     8   9.0     8
# 12      13  focused     6   5.0     9
# 13      14  focused     8   8.0     7
# 14      15  focused     8   8.0     7
# 15      16  focused     6   8.0     7
# 16      17  focused     7   7.0     6
# 17      18  focused     7   8.0     6
# 18      19  focused     5   6.0     6
# 19      20  focused     6   6.0     5
# Le mode est : 5.5
